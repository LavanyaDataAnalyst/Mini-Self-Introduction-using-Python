# %%
Name = 'Lavanya Madhan Raj'

# %%
Age = 27

# %%
City = 'Chennai'

# %%
Degree = 'M.SC Physics, B.ED'

# %%
Course = 'AI driven Data Analytics'

# %%
Skills_Learned = 'Excel, PowerBI, SQL'

# %%
Currently_Learning = 'Python'

# %%
Is_course_completed = 'False'

# %%
print('---------- My Intro ----------\n','My name is', Name,'\n','I am',int(Age),'years old',"\n",'I am currently living in',City,'\n','I hold',Degree,'degree','\n','I am currently pursuing',Course,'course','\n','I have developed my skills in',Skills_Learned,'\n','Now I am currently learning',Currently_Learning)
# Out:
# ---------- My Intro ----------
#  My name is Lavanya Madhan Raj
#  I am 27 years old
#  I am currently living in Chennai
#  I hold M.SC Physics, B.ED degree
#  I am currently pursuing AI driven Data Analytics course
#  I have developed my skills in Excel, PowerBI, SQL
#  Now I am currently learning Python
